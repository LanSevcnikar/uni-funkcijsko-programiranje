# %%
from SignalModule import SignalGenerator, Signal
from SlidingWindowModule import SlidingWindow
from pyRiser import Ripser


from ripser import ripser
from persim import plot_diagrams

import numpy as np

# %%
# sin function, no noise, from 0 to 5 with step 0.1
function = lambda x: 2*np.sin(x/3)
start_time = 0
end_time = 60
step = 0.5
noise = 0.11

signalGenerator = SignalGenerator(
    start=start_time,
    end=end_time,
    step=step,
    function=function,
    noise=noise,
)
signal = signalGenerator.generate()

# %%
signal.plot()

# %%
M = 20
tau = 0.31

slidingWindow = SlidingWindow(
    signal = signal,
    M = M,
    tau = tau
)
slidingWindow.print_first_n(5)
slidingWindow.plot(d=2)
# Out:
# Point 0: (0.0, array([-0.01937586,  0.43636528,  0.71249818,  0.71249818,  0.8791408 ,
#         1.23582205,  1.23582205,  1.52904754,  1.52904754,  1.62546761,
#         1.78167159,  1.78167159,  1.99398641,  2.08937303,  2.08937303,
#         2.00208446,  2.00208446,  2.01181118,  1.79845032,  1.79845032]), array([0.8 , 0.16, 0.16]))
# Point 1: (0.5, array([0.43636528, 0.71249818, 0.8791408 , 0.8791408 , 1.23582205,
#        1.52904754, 1.52904754, 1.62546761, 1.62546761, 1.78167159,
#        1.99398641, 1.99398641, 2.08937303, 2.00208446, 2.00208446,
#        2.01181118, 2.01181118, 1.79845032, 1.59691073, 1.59691073]), array([0.8  , 0.352, 0.16 ]))
# Point 2: (1.0, array([0.71249818, 0.8791408 , 1.23582205, 1.23582205, 1.52904754,
#        1.62546761, 1.62546761, 1.78167159, 1.78167159, 1.99398641,
#        2.08937303, 2.08937303, 2.00208446, 2.01181118, 2.01181118,
#        1.79845032, 1.79845032, 1.59691073, 1.37680291, 1.37680291]), array([0.8  , 0.544, 0.16 ]))
# Point 3: (1.5, array([0.8791408 , 1.23582205, 1.52904754, 1.52904754, 1.62546761,
#        1.78167159, 1.78167159, 1.99398641, 1.99398641, 2.08937303,
#        2.00208446, 2.00208446, 2.01181118, 1.79845032, 1.79845032,
#        1.59691073, 1.59691073, 1.37680291, 1.14631164, 1.14631164]), array([0.8  , 0.736, 0.16 ]))
# Point 4: (2.0, array([1.23582205, 1.52904754, 1.62546761, 1.62546761, 1.78167159,
#        1.99398641, 1.99398641, 2.08937303, 2.08937303, 2.00208446,
#        2.01181118, 2.01181118, 1.79845032, 1.59691073, 1.59691073,
#        1.37680291, 1.37680291, 1.14631164, 1.00950586, 1.00950586]), array([0.672, 0.8  , 0.16 ]))

# %%
diagrams = ripser(
    X=slidingWindow.get_distance_matrix(),
    maxdim=2,
    distance_matrix=True

)["dgms"]
plot_diagrams(diagrams, show=True)

# %%
diagrams
# Out:
# [array([[0.        , 0.30913067],
#         [0.        , 0.32955822],
#         [0.        , 0.34010169],
#         [0.        , 0.35519883],
#         [0.        , 0.35903549],
#         [0.        , 0.37528187],
#         [0.        , 0.39011276],
#         [0.        , 0.39358991],
#         [0.        , 0.39712182],
#         [0.        , 0.40222013],
#         [0.        , 0.41776565],
#         [0.        , 0.41845638],
#         [0.        , 0.42172015],
#         [0.        , 0.42228341],
#         [0.        , 0.434089  ],
#         [0.        , 0.43838391],
#         [0.        , 0.44377375],
#         [0.        , 0.4456197 ],
#         [0.        , 0.44646046],
#         [0.        , 0.4482626 ],
#         [0.        , 0.45126367],
#         [0.        , 0.45151073],
#         [0.        , 0.45525947],
#         [0.        , 0.45732722],
#         [0.        , 0.45973122],
#         [0.        , 0.46321598],
#         [0.        , 0.46414387],
#         [0.        , 0.46487454],
#         [0.        , 0.4685156 ],
#         [0.        , 0.46928465],
#         [0.        , 0.47170228],
#         [0.        , 0.47333631],
#         [0.        , 0.47683564],
#         [0.        , 0.4778555 ],
#         [0.        , 0.48097518],
#         [0.        , 0.48136345],
#         [0.        , 0.4828352 ],
#         [0.        , 0.48345688],
#         [0.        , 0.48768511],
#         [0.        , 0.49036014],
#         [0.        , 0.49282172],
#         [0.        , 0.49500757],
#         [0.        , 0.4958286 ],
#         [0.        , 0.49840665],
#         [0.        , 0.49883392],
#         [0.        , 0.50474072],
#         [0.        , 0.50522834],
#         [0.        , 0.50835204],
#         [0.        , 0.51144576],
#         [0.        , 0.51684254],
#         [0.        , 0.5215196 ],
#         [0.        , 0.5215857 ],
#         [0.        , 0.52344668],
#         [0.        , 0.52352798],
#         [0.        , 0.52437437],
#         [0.        , 0.53352493],
#         [0.        , 0.53463691],
#         [0.        , 0.53659451],
#         [0.        , 0.53684264],
#         [0.        , 0.54236454],
#         [0.        , 0.5439713 ],
#         [0.        , 0.54461068],
#         [0.        , 0.54500085],
#         [0.        , 0.54702795],
#         [0.        , 0.54751515],
#         [0.        , 0.54851228],
#         [0.        , 0.54928184],
#         [0.        , 0.5521723 ],
#         [0.        , 0.55243999],
#         [0.        , 0.556216  ],
#         [0.        , 0.55654168],
#         [0.        , 0.55965513],
#         [0.        , 0.56413108],
#         [0.        , 0.56814575],
#         [0.        , 0.57384831],
#         [0.        , 0.57893509],
#         [0.        , 0.58090818],
#         [0.        , 0.58228952],
#         [0.        , 0.58304054],
#         [0.        , 0.59109408],
#         [0.        , 0.59325647],
#         [0.        , 0.60736454],
#         [0.        , 0.60882097],
#         [0.        , 0.61007667],
#         [0.        , 0.61565894],
#         [0.        , 0.62099743],
#         [0.        , 0.62128943],
#         [0.        , 0.62376058],
#         [0.        , 0.62761772],
#         [0.        , 0.63298333],
#         [0.        , 0.63469613],
#         [0.        , 0.63972843],
#         [0.        , 0.64524078],
#         [0.        , 0.6481083 ],
#         [0.        , 0.64973372],
#         [0.        , 0.65036452],
#         [0.        , 0.65997863],
#         [0.        , 0.66082281],
#         [0.        , 0.66786993],
#         [0.        , 0.67423272],
#         [0.        , 0.67588592],
#         [0.        , 0.69660842],
#         [0.        , 0.74335623],
#         [0.        , 0.74632931],
#         [0.        , 0.76187503],
#         [0.        , 0.76537329],
#         [0.        , 0.78296149],
#         [0.        , 0.81287044],
#         [0.        ,        inf]]),
#  array([[0.83064759, 9.40308857]]),
#  array([[9.47492123, 9.48898792]])]

# %%
import numpy as np
import matplotlib.pyplot as plt



plot_persistances_dim1(diagrams)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 6 plot_persistances_dim1(diagrams)
#
# NameError: name 'plot_persistances_dim1' is not defined

# %%
barcode_distances = [y - x for x,y in diagrams[1]]
max_distance = max(barcode_distances)
print(max_distance)
# Out:
# 4.843635231256485
