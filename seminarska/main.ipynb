# %%
from SignalModule import SignalGenerator, Signal
from SlidingWindowModule import SlidingWindow
from pyRiser import Ripser

import numpy as np

# %%
# sin function, no noise, from 0 to 5 with step 0.1
function = lambda x: np.sin(x)
start_time = 0
end_time = 20
step = 0.2
noise = 0

signalGenerator = SignalGenerator(
    start=start_time,
    end=end_time,
    step=step,
    function=function,
    noise=noise,
)
signal = signalGenerator.generate()

# %%
signal.plot()

# %%
M = 10
tau = 0.1

slidingWindow = SlidingWindow(
    signal = signal,
    M = M,
    tau = tau
)
slidingWindow.print_first_n(5)
slidingWindow.plot(d=3)
# Out:
# Point 0: (0.0, array([0.        , 0.19866933, 0.19866933, 0.38941834, 0.38941834,
#        0.56464247, 0.56464247, 0.71735609, 0.71735609, 0.84147098]), array([0.8 , 0.16, 0.16]))
# Point 1: (0.2, array([0.19866933, 0.38941834, 0.38941834, 0.56464247, 0.56464247,
#        0.71735609, 0.71735609, 0.84147098, 0.84147098, 0.93203909]), array([0.8   , 0.2368, 0.16  ]))
# Point 2: (0.4, array([0.38941834, 0.56464247, 0.56464247, 0.71735609, 0.71735609,
#        0.84147098, 0.84147098, 0.93203909, 0.98544973, 0.98544973]), array([0.8   , 0.3136, 0.16  ]))
# Point 3: (0.6000000000000001, array([0.56464247, 0.71735609, 0.71735609, 0.84147098, 0.84147098,
#        0.93203909, 0.98544973, 0.98544973, 0.9995736 , 0.9995736 ]), array([0.8   , 0.3904, 0.16  ]))
# Point 4: (0.8, array([0.71735609, 0.84147098, 0.84147098, 0.93203909, 0.98544973,
#        0.98544973, 0.9995736 , 0.9995736 , 0.97384763, 0.97384763]), array([0.8   , 0.4672, 0.16  ]))

# %%
# Might be smart to do this later 
# https://github.com/Ripser/ripser?tab=readme-ov-file
# but not right now

# %%
ripser = Ripser("/home/lan-sevcnikar/Documents/university/funkcijsko programiranje/seminarska/ripser/ripser", dim=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 import os
# ----> 2 self.cmd_path = os.path.join(os.path.dirname(__file__), "ripser")
#       4 ripser = Ripser(self.cmd_path, dim=1)
#
# NameError: name '__file__' is not defined

# %%
ripser.compute_pd(slidingWindow.get_distance_matrix())
# Out:
# Serializing to disk:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Ripser:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ripser.compute_pd(slidingWindow.get_distance_matrix())
#
# File ~/Documents/university/funkcijsko programiranje/seminarska/pyRiser.py:107, in Ripser.compute_pd(self, dist_matrices)
#     105 pers_diags = []
#     106 for mat_file in tqdm(file_list, desc='Running Ripser'):
# --> 107     pers_diags.append(self.call(mat_file))
#     109 shutil.rmtree(temp_dir)
#     111 return pers_diags
#
# File ~/Documents/university/funkcijsko programiranje/seminarska/pyRiser.py:75, in Ripser.call(self, filename)
#      74 def call(self, filename):
# ---> 75     result = subprocess.run([self.cmd_path, '--dim', str(self.dim), '--format', 'distance', filename],
#      76                             stdout=subprocess.PIPE)
#      77     return self.parse_output(result.stdout)
#
# File ~/anaconda3/lib/python3.11/subprocess.py:619, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     616     kwargs["stdout"] = PIPE
#     617     kwargs["stderr"] = PIPE
# --> 619 with Popen(*popenargs, **kwargs) as process:
#     620     try:
#     621         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1140, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1135         if self.text_mode:
#    1136             self.stderr = io.TextIOWrapper(
#    1137                 self.stderr, encoding=encoding, errors=errors
#    1138             )
# -> 1140     self._execute_child(
#    1141         args,
#    1142         executable,
#    1143         preexec_fn,
#    1144         close_fds,
#    1145         pass_fds,
#    1146         cwd,
#    1147         env,
#    1148         startupinfo,
#    1149         creationflags,
#    1150         shell,
#    1151         p2cread,
#    1152         p2cwrite,
#    1153         c2pread,
#    1154         c2pwrite,
#    1155         errread,
#    1156         errwrite,
#    1157         restore_signals,
#    1158         gid,
#    1159         gids,
#    1160         uid,
#    1161         umask,
#    1162         start_new_session,
#    1163         process_group,
#    1164     )
#    1165 except:
#    1166     # Cleanup if the child failed starting.
#    1167     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/lib/python3.11/subprocess.py:2164, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    2162     if errno_num != 0:
#    2163         err_msg = os.strerror(errno_num)
# -> 2164     raise child_exception_type(errno_num, err_msg, err_filename)
#    2165 raise child_exception_type(err_msg)
#
# PermissionError: [Errno 13] Permission denied: './ripser'
