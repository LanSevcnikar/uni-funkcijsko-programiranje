# %%
from SignalModule import SignalGenerator, Signal
from SlidingWindowModule import SlidingWindow
from pyRiser import Ripser


from ripser import ripser
from persim import plot_diagrams

import numpy as np

# %%
# sin function, no noise, from 0 to 5 with step 0.1
function = lambda x: np.sin(x)
start_time = 0
end_time = 20
step = 0.05
noise = 0.11

signalGenerator = SignalGenerator(
    start=start_time,
    end=end_time,
    step=step,
    function=function,
    noise=noise,
)
signal = signalGenerator.generate()

# %%
signal.plot()

# %%
M = 20
tau = 0.31

slidingWindow = SlidingWindow(
    signal = signal,
    M = M,
    tau = tau
)
slidingWindow.print_first_n(5)
slidingWindow.plot(d=3)
# Out:
# Point 0: (0.0, array([-0.05506283,  0.42238563,  0.67977668,  0.86611202,  0.89864967,
#         0.96659214,  1.01048065,  0.75581325,  0.54735042,  0.32710683,
#         0.02427024, -0.2564217 , -0.5633999 , -0.76666177, -0.89183404,
#        -0.95856569, -0.9292261 , -0.92218152, -0.70104636, -0.4116158 ]), array([0.8 , 0.16, 0.16]))
# Point 1: (0.05, array([ 0.10256281,  0.49382092,  0.53827221,  0.74509829,  1.00434111,
#         0.91069055,  0.98609265,  0.6843218 ,  0.63734852,  0.22279628,
#        -0.03666225, -0.34833581, -0.6066922 , -0.86226792, -0.94945939,
#        -0.94083187, -0.91731693, -0.85414664, -0.62827983, -0.22165864]), array([0.8   , 0.1792, 0.16  ]))
# Point 2: (0.1, array([ 0.0150118 ,  0.36047738,  0.66037464,  0.83582763,  1.05965229,
#         1.01310676,  0.85255494,  0.78004704,  0.55510988,  0.22805042,
#        -0.06473392, -0.37360831, -0.73974698, -0.87810551, -1.02376199,
#        -1.07285284, -1.01195448, -0.83288885, -0.64588474, -0.20954992]), array([0.8   , 0.1984, 0.16  ]))
# Point 3: (0.15000000000000002, array([ 0.05851881,  0.42639105,  0.72517508,  0.84537746,  1.06894204,
#         0.96836621,  0.93627382,  0.68334099,  0.37735898,  0.09127675,
#        -0.09480494, -0.36966132, -0.788754  , -0.87197157, -1.00043551,
#        -0.9953829 , -0.99907547, -0.84126056, -0.52781203, -0.12498795]), array([0.8   , 0.2176, 0.16  ]))
# Point 4: (0.2, array([ 0.17180879,  0.52787398,  0.79805574,  0.95285242,  0.91835667,
#         1.06197592,  0.90220176,  0.68292314,  0.45980446,  0.14539069,
#        -0.14830526, -0.42074608, -0.78789897, -0.97543593, -1.0095252 ,
#        -0.90867605, -0.94426544, -0.73517495, -0.5279642 , -0.25029083]), array([0.8   , 0.2368, 0.16  ]))

# %%
diagrams = ripser(
    X=slidingWindow.get_distance_matrix(),
    maxdim=2,
    distance_matrix=True

)["dgms"]
plot_diagrams(diagrams, show=True)

# %%
barcode_distances = [y - x for x,y in diagrams[1]]
max_distance = max(barcode_distances)
print(max_distance)
# Out:
# 4.947282612323761
